# %% [markdown]
# ### Bayesian Optimization을 이용하여 application과 previous로 만들어진 집합의 하이퍼 파라미터 튜닝

# %% [markdown]
# #### 라이브러리 및 데이터 세트 로딩. 이전 application 데이터의 FE 함수 복사

# %%
import numpy as np
import pandas as pd
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %%
def get_dataset():
    app_train = pd.read_csv('./home-credit-default-risk/application_train.csv')
    app_test = pd.read_csv('./home-credit-default-risk/application_test.csv')
    apps = pd.concat([app_train, app_test])
    prev = pd.read_csv('./home-credit-default-risk/previous_application.csv')

    return apps, prev

apps, prev = get_dataset()

# %% [markdown]
# #### 이전 application 데이터의 feature engineering 함수 복사

# %%
def get_apps_processed(apps):
    
    # EXT_SOURCE_X FEATURE 가공
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    # AMT_CREDIT 비율로 Feature 가공
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_CREDIT']
    
    # AMT_INCOME_TOTAL 비율로 Feature 가공
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT']/apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['CNT_FAM_MEMBERS']
    
    # DAYS_BIRTH, DAYS_EMPLOYED 비율로 Feature 가공
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED']/apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %% [markdown]
# #### previous 데이터 가공후 인코딩 및 최종 데이터 집합 생성하는 함수 선언

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

def get_prev_processed(prev):
    # 대출 신청 금액과 실제 대출액/대출 상품금액 차이 및 비율
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT']/prev['AMT_APPLICATION']
    # prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY']/prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE']/prev['AMT_APPLICATION']
    
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # 첫번째 만기일과 마지막 만기일까지의 기간
    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    # 매월 납부 금액과 납부 횟수 곱해서 전체 납부 금액 구함. 
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    # 전체 납부 금액 대비 AMT_CREDIT 비율을 구하고 여기에 다시 납부횟수로 나누어서 이자율 계산. 
    prev['PREV_INTERESTS_RATE'] = (all_pay/prev['AMT_CREDIT'] - 1)/prev['CNT_PAYMENT']
        
    return prev
    
    
def get_prev_amt_agg(prev):
    # 새롭게 생성된 대출 신청액 대비 다른 금액 차이 및 비율로 aggregation 수행. 
    agg_dict = {
         # 기존 컬럼. 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 가공 컬럼
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }

    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)

    # multi index 컬럼을 '_'로 연결하여 컬럼명 변경
    prev_amt_agg.columns = ["PREV_"+ "_".join(x).upper() for x in prev_amt_agg.columns.ravel()]
    
    return prev_amt_agg

def get_prev_refused_appr_agg(prev):
    # 원래 groupby 컬럼 + 세부 기준 컬럼으로 groupby 수행. 세분화된 레벨로 aggregation 수행 한 뒤에 unstack()으로 컬럼레벨로 변형. 
    prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby([ 'SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
    prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
    # 컬럼명 변경. 
    prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT' ]
    # NaN값은 모두 0으로 변경. 
    prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)
    
    return prev_refused_appr_agg

    

def get_prev_agg(prev):
    prev = get_prev_processed(prev)
    prev_amt_agg = get_prev_amt_agg(prev)
    prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
    
    # prev_amt_agg와 조인. 
    prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
    # SK_ID_CURR별 과거 대출건수 대비 APPROVED_COUNT 및 REFUSED_COUNT 비율 생성. 
    prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    # 'PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT' 컬럼 drop 
    prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
    
    return prev_agg

def get_apps_all_with_prev_agg(apps, prev):
    apps_all =  get_apps_processed(apps)
    prev_agg = get_prev_agg(prev)
    print('prev_agg shape:', prev_agg.shape)
    print('apps_all before merge shape:', apps_all.shape)
    apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
    print('apps_all after merge with prev_agg shape:', apps_all.shape)
    
    return apps_all

def get_apps_all_encoded(apps_all):
    object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
    for column in object_columns:
        apps_all[column] = pd.factorize(apps_all[column])[0]
    
    return apps_all

def get_apps_all_train_test(apps_all):
    apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
    apps_all_test = apps_all[apps_all['TARGET'].isnull()]

    apps_all_test = apps_all_test.drop('TARGET', axis=1)
    
    return apps_all_train, apps_all_test
    
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=2000,
                learning_rate=0.01,
                num_leaves=32,
                colsample_bytree=0.8,
                subsample=0.8,
                max_depth=8,
                reg_alpha=0.04,
                reg_lambda=0.07,
                min_child_weight=40,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %% [markdown]
# ##### 최종 집합 생성 및 인코딩, 학습/테스트 데이터 분리, 학습/검증 피처와 타겟 데이터 분리

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)

# %% [markdown]
# #### Bayesian Optimization

# %%
# bayesian optimization 패키지 설치
#!pip install bayesian-optimization

# %%
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

# %% [markdown]
# ##### 함수의 입력값 search 범위(하이퍼 파라미터 별 입력 범위) 를 설정

# %%
bayesian_params = {
    'max_depth': (6, 16),
    'num_leaves': (24, 64),
    'min_child_samples': (10, 200),
    'min_child_weight': (1, 50),
    'subsample': (0.5, 1),
    'colsample_bytree': (0.5, 1),
    'max_bin': (10, 500),
    'reg_lambda': (0.001, 10),
    'reg_alpha': (0.01, 50)
}

# %% [markdown]
# ##### 최대 값을 구할 함수 선언.
# * iteration 시 마다 hyperparameter를 입력받아 classifier 학습하고 roc_auc_score값을 반환

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight,
                subsample, colsample_bytree, max_bin, reg_lambda, reg_alpha):
    params = {
        "n_estimators":500, "learning_rate":0.02,
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0), 
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0)
    }
    
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
    roc_auc = roc_auc_score(valid_y, valid_proba)
    
    return roc_auc

# %% [markdown]
# ##### BayesianOptimization 객체 생성 후 함수 반환값이 최대가 되는 입력값 search를 위한 iteration 수행

# %%
lgbBO = BayesianOptimization(lgb_roc_eval, bayesian_params, random_state=0)

lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.769662	training's binary_logloss: 0.246032	valid_1's auc: 0.755483	valid_1's binary_logloss: 0.248917
# [200]	training's auc: 0.787253	training's binary_logloss: 0.238487	valid_1's auc: 0.766224	valid_1's binary_logloss: 0.244243
# [300]	training's auc: 0.798898	training's binary_logloss: 0.23398	valid_1's auc: 0.771467	valid_1's binary_logloss: 0.242344
# [400]	training's auc: 0.807869	training's binary_logloss: 0.23065	valid_1's auc: 0.773972	valid_1's binary_logloss: 0.241458
# [500]	training's auc: 0.815952	training's binary_logloss: 0.227669	valid_1's auc: 0.775806	valid_1's binary_logloss: 0.240831
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815952	training's binary_logloss: 0.227669	valid_1's auc: 0.775806	valid_1's binary_logloss: 0.240831
# |  1        |  0.7758   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.76256	training's binary_logloss: 0.247457	valid_1's auc: 0.7537	valid_1's binary_logloss: 0.249099
# [200]	training's auc: 0.780205	training's binary_logloss: 0.24047	valid_1's auc: 0.765756	valid_1's binary_logloss: 0.244226
# [300]	training's auc: 0.79096	training's binary_logloss: 0.236494	valid_1's auc: 0.771277	valid_1's binary_logloss: 0.242257
# [400]	training's auc: 0.799197	training's binary_logloss: 0.233538	valid_1's auc: 0.774065	valid_1's binary_logloss: 0.241249
# [500]	training's auc: 0.806064	training's binary_logloss: 0.231061	valid_1's auc: 0.775612	valid_1's binary_logloss: 0.2407
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.806064	training's binary_logloss: 0.231061	valid_1's auc: 0.775612	valid_1's binary_logloss: 0.2407
# |  2        |  0.7756   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775644	training's binary_logloss: 0.243872	valid_1's auc: 0.757262	valid_1's binary_logloss: 0.247984
# [200]	training's auc: 0.796903	training's binary_logloss: 0.235046	valid_1's auc: 0.768757	valid_1's binary_logloss: 0.243207
# [300]	training's auc: 0.812041	training's binary_logloss: 0.229261	valid_1's auc: 0.773366	valid_1's binary_logloss: 0.24156
# [400]	training's auc: 0.824984	training's binary_logloss: 0.224423	valid_1's auc: 0.77625	valid_1's binary_logloss: 0.240565
# [500]	training's auc: 0.835718	training's binary_logloss: 0.22036	valid_1's auc: 0.777331	valid_1's binary_logloss: 0.240167
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835718	training's binary_logloss: 0.22036	valid_1's auc: 0.777331	valid_1's binary_logloss: 0.240167
# |  3        |  0.7773   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765842	training's binary_logloss: 0.246884	valid_1's auc: 0.753808	valid_1's binary_logloss: 0.249258
# [200]	training's auc: 0.783137	training's binary_logloss: 0.239739	valid_1's auc: 0.765526	valid_1's binary_logloss: 0.244489
# [300]	training's auc: 0.793648	training's binary_logloss: 0.23577	valid_1's auc: 0.770579	valid_1's binary_logloss: 0.242643
# [400]	training's auc: 0.801582	training's binary_logloss: 0.232812	valid_1's auc: 0.773253	valid_1's binary_logloss: 0.241685
# [500]	training's auc: 0.808263	training's binary_logloss: 0.23033	valid_1's auc: 0.774967	valid_1's binary_logloss: 0.24108
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808263	training's binary_logloss: 0.23033	valid_1's auc: 0.774967	valid_1's binary_logloss: 0.24108
# |  4        |  0.775    |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.7659	training's binary_logloss: 0.247276	valid_1's auc: 0.753968	valid_1's binary_logloss: 0.24956
# [200]	training's auc: 0.781741	training's binary_logloss: 0.240327	valid_1's auc: 0.764668	valid_1's binary_logloss: 0.244831
# [300]	training's auc: 0.791758	training's binary_logloss: 0.236503	valid_1's auc: 0.769722	valid_1's binary_logloss: 0.242955
# [400]	training's auc: 0.799313	training's binary_logloss: 0.233722	valid_1's auc: 0.772473	valid_1's binary_logloss: 0.241976
# [500]	training's auc: 0.805605	training's binary_logloss: 0.231421	valid_1's auc: 0.774035	valid_1's binary_logloss: 0.241428
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805605	training's binary_logloss: 0.231421	valid_1's auc: 0.774035	valid_1's binary_logloss: 0.241428
# |  5        |  0.774    |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.778416	training's binary_logloss: 0.243866	valid_1's auc: 0.758906	valid_1's binary_logloss: 0.248045
# [200]	training's auc: 0.797547	training's binary_logloss: 0.235078	valid_1's auc: 0.768769	valid_1's binary_logloss: 0.243239
# [300]	training's auc: 0.812388	training's binary_logloss: 0.229334	valid_1's auc: 0.773393	valid_1's binary_logloss: 0.241516
# [400]	training's auc: 0.824856	training's binary_logloss: 0.224602	valid_1's auc: 0.77606	valid_1's binary_logloss: 0.240581
# [500]	training's auc: 0.835757	training's binary_logloss: 0.220492	valid_1's auc: 0.777391	valid_1's binary_logloss: 0.240112
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835757	training's binary_logloss: 0.220492	valid_1's auc: 0.777391	valid_1's binary_logloss: 0.240112
# |  6        |  0.7774   |  0.6405   |  435.0    |  13.5     |  169.3    |  26.92    |  57.69    |  5.768    |  9.196    |  0.613    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.768986	training's binary_logloss: 0.246605	valid_1's auc: 0.754105	valid_1's binary_logloss: 0.249397
# [200]	training's auc: 0.785414	training's binary_logloss: 0.239463	valid_1's auc: 0.765351	valid_1's binary_logloss: 0.244624
# [300]	training's auc: 0.794865	training's binary_logloss: 0.235677	valid_1's auc: 0.770288	valid_1's binary_logloss: 0.242789
# [400]	training's auc: 0.801967	training's binary_logloss: 0.232902	valid_1's auc: 0.772929	valid_1's binary_logloss: 0.241817
# [500]	training's auc: 0.807987	training's binary_logloss: 0.230625	valid_1's auc: 0.774579	valid_1's binary_logloss: 0.241227
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.807987	training's binary_logloss: 0.230625	valid_1's auc: 0.774579	valid_1's binary_logloss: 0.241227
# |  7        |  0.7746   |  0.9148   |  488.7    |  7.188    |  187.6    |  17.14    |  62.7     |  34.78    |  7.949    |  0.9046   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776113	training's binary_logloss: 0.244087	valid_1's auc: 0.758488	valid_1's binary_logloss: 0.247925
# [200]	training's auc: 0.795984	training's binary_logloss: 0.235491	valid_1's auc: 0.768933	valid_1's binary_logloss: 0.243191
# [300]	training's auc: 0.810008	training's binary_logloss: 0.230053	valid_1's auc: 0.773314	valid_1's binary_logloss: 0.241552
# [400]	training's auc: 0.822244	training's binary_logloss: 0.225472	valid_1's auc: 0.776184	valid_1's binary_logloss: 0.24053
# [500]	training's auc: 0.832437	training's binary_logloss: 0.221621	valid_1's auc: 0.777527	valid_1's binary_logloss: 0.240041
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832437	training's binary_logloss: 0.221621	valid_1's auc: 0.777527	valid_1's binary_logloss: 0.240041
# |  8        |  0.7775   |  0.7366   |  404.5    |  10.48    |  178.6    |  7.607    |  51.92    |  4.212    |  7.624    |  0.8729   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776884	training's binary_logloss: 0.244363	valid_1's auc: 0.757931	valid_1's binary_logloss: 0.248329
# [200]	training's auc: 0.795476	training's binary_logloss: 0.235896	valid_1's auc: 0.767942	valid_1's binary_logloss: 0.243577
# [300]	training's auc: 0.809275	training's binary_logloss: 0.230547	valid_1's auc: 0.77254	valid_1's binary_logloss: 0.241869
# [400]	training's auc: 0.82066	training's binary_logloss: 0.226218	valid_1's auc: 0.774854	valid_1's binary_logloss: 0.241044
# [500]	training's auc: 0.830938	training's binary_logloss: 0.222269	valid_1's auc: 0.776395	valid_1's binary_logloss: 0.240484
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830938	training's binary_logloss: 0.222269	valid_1's auc: 0.776395	valid_1's binary_logloss: 0.240484
# |  9        |  0.7764   |  0.7749   |  388.9    |  14.3     |  193.9    |  49.91    |  62.85    |  13.15    |  9.906    |  0.6812   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.770336	training's binary_logloss: 0.246651	valid_1's auc: 0.754599	valid_1's binary_logloss: 0.249585
# [200]	training's auc: 0.786354	training's binary_logloss: 0.23927	valid_1's auc: 0.765073	valid_1's binary_logloss: 0.244723
# [300]	training's auc: 0.796325	training's binary_logloss: 0.235269	valid_1's auc: 0.770114	valid_1's binary_logloss: 0.242828
# [400]	training's auc: 0.804165	training's binary_logloss: 0.232277	valid_1's auc: 0.772877	valid_1's binary_logloss: 0.241849
# [500]	training's auc: 0.810807	training's binary_logloss: 0.229784	valid_1's auc: 0.774429	valid_1's binary_logloss: 0.241275
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.810807	training's binary_logloss: 0.229784	valid_1's auc: 0.774429	valid_1's binary_logloss: 0.241275
# |  10       |  0.7744   |  0.7827   |  413.0    |  8.384    |  147.3    |  3.612    |  61.47    |  39.48    |  8.613    |  0.7416   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.781523	training's binary_logloss: 0.242389	valid_1's auc: 0.760069	valid_1's binary_logloss: 0.247396
# [200]	training's auc: 0.803256	training's binary_logloss: 0.232954	valid_1's auc: 0.769959	valid_1's binary_logloss: 0.242813
# [300]	training's auc: 0.818656	training's binary_logloss: 0.226824	valid_1's auc: 0.773664	valid_1's binary_logloss: 0.241364
# [400]	training's auc: 0.831356	training's binary_logloss: 0.221925	valid_1's auc: 0.775626	valid_1's binary_logloss: 0.240665
# [500]	training's auc: 0.842643	training's binary_logloss: 0.217585	valid_1's auc: 0.776864	valid_1's binary_logloss: 0.240238
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.842643	training's binary_logloss: 0.217585	valid_1's auc: 0.776864	valid_1's binary_logloss: 0.240238
# |  11       |  0.7769   |  0.7784   |  432.3    |  9.276    |  156.2    |  19.58    |  62.23    |  2.791    |  3.411    |  0.9414   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.764148	training's binary_logloss: 0.247721	valid_1's auc: 0.755217	valid_1's binary_logloss: 0.249348
# [200]	training's auc: 0.780038	training's binary_logloss: 0.240707	valid_1's auc: 0.765888	valid_1's binary_logloss: 0.244325
# [300]	training's auc: 0.790881	training's binary_logloss: 0.236674	valid_1's auc: 0.771302	valid_1's binary_logloss: 0.242317
# [400]	training's auc: 0.799337	training's binary_logloss: 0.233641	valid_1's auc: 0.774437	valid_1's binary_logloss: 0.241211
# [500]	training's auc: 0.806339	training's binary_logloss: 0.231119	valid_1's auc: 0.776223	valid_1's binary_logloss: 0.240572
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.806339	training's binary_logloss: 0.231119	valid_1's auc: 0.776223	valid_1's binary_logloss: 0.240572
# |  12       |  0.7762   |  0.5333   |  435.5    |  11.75    |  184.6    |  1.646    |  27.48    |  2.83     |  5.427    |  0.9507   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.771767	training's binary_logloss: 0.245245	valid_1's auc: 0.756556	valid_1's binary_logloss: 0.248439
# [200]	training's auc: 0.790316	training's binary_logloss: 0.237276	valid_1's auc: 0.767658	valid_1's binary_logloss: 0.24363
# [300]	training's auc: 0.803383	training's binary_logloss: 0.232334	valid_1's auc: 0.77253	valid_1's binary_logloss: 0.241876
# [400]	training's auc: 0.814178	training's binary_logloss: 0.228314	valid_1's auc: 0.775457	valid_1's binary_logloss: 0.240833
# [500]	training's auc: 0.823267	training's binary_logloss: 0.224935	valid_1's auc: 0.776807	valid_1's binary_logloss: 0.240352
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.823267	training's binary_logloss: 0.224935	valid_1's auc: 0.776807	valid_1's binary_logloss: 0.240352
# |  13       |  0.7768   |  0.8217   |  408.5    |  12.66    |  176.8    |  13.56    |  45.71    |  8.573    |  9.075    |  0.944    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772342	training's binary_logloss: 0.244632	valid_1's auc: 0.757289	valid_1's binary_logloss: 0.24801
# [200]	training's auc: 0.792992	training's binary_logloss: 0.236256	valid_1's auc: 0.768391	valid_1's binary_logloss: 0.243282
# [300]	training's auc: 0.807269	training's binary_logloss: 0.230918	valid_1's auc: 0.773031	valid_1's binary_logloss: 0.241587
# [400]	training's auc: 0.819126	training's binary_logloss: 0.226659	valid_1's auc: 0.77551	valid_1's binary_logloss: 0.240735
# [500]	training's auc: 0.829573	training's binary_logloss: 0.222961	valid_1's auc: 0.776617	valid_1's binary_logloss: 0.240338
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829573	training's binary_logloss: 0.222961	valid_1's auc: 0.776617	valid_1's binary_logloss: 0.240338
# |  14       |  0.7766   |  0.807    |  383.6    |  9.689    |  197.9    |  1.59     |  40.71    |  1.108    |  0.526    |  0.7566   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.770605	training's binary_logloss: 0.245737	valid_1's auc: 0.754941	valid_1's binary_logloss: 0.248789
# [200]	training's auc: 0.788574	training's binary_logloss: 0.238322	valid_1's auc: 0.766056	valid_1's binary_logloss: 0.24419
# [300]	training's auc: 0.79902	training's binary_logloss: 0.234133	valid_1's auc: 0.770941	valid_1's binary_logloss: 0.242377
# [400]	training's auc: 0.807073	training's binary_logloss: 0.231073	valid_1's auc: 0.773425	valid_1's binary_logloss: 0.241518
# [500]	training's auc: 0.813956	training's binary_logloss: 0.228457	valid_1's auc: 0.774863	valid_1's binary_logloss: 0.240992
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.813956	training's binary_logloss: 0.228457	valid_1's auc: 0.774863	valid_1's binary_logloss: 0.240992
# |  15       |  0.7749   |  0.9907   |  404.3    |  6.113    |  176.8    |  12.76    |  55.42    |  12.21    |  2.73     |  0.6065   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.778663	training's binary_logloss: 0.243716	valid_1's auc: 0.759425	valid_1's binary_logloss: 0.247821
# [200]	training's auc: 0.797929	training's binary_logloss: 0.23518	valid_1's auc: 0.768782	valid_1's binary_logloss: 0.243245
# [300]	training's auc: 0.810327	training's binary_logloss: 0.230206	valid_1's auc: 0.772847	valid_1's binary_logloss: 0.241676
# [400]	training's auc: 0.819831	training's binary_logloss: 0.226461	valid_1's auc: 0.774909	valid_1's binary_logloss: 0.240925
# [500]	training's auc: 0.828485	training's binary_logloss: 0.223175	valid_1's auc: 0.776169	valid_1's binary_logloss: 0.240469
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.828485	training's binary_logloss: 0.223175	valid_1's auc: 0.776169	valid_1's binary_logloss: 0.240469
# |  16       |  0.7762   |  0.6745   |  427.9    |  7.442    |  159.7    |  22.3     |  59.72    |  5.482    |  2.534    |  0.9366   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773776	training's binary_logloss: 0.244857	valid_1's auc: 0.756947	valid_1's binary_logloss: 0.248455
# [200]	training's auc: 0.792389	training's binary_logloss: 0.236716	valid_1's auc: 0.767456	valid_1's binary_logloss: 0.243729
# [300]	training's auc: 0.805451	training's binary_logloss: 0.23171	valid_1's auc: 0.772311	valid_1's binary_logloss: 0.241972
# [400]	training's auc: 0.816394	training's binary_logloss: 0.227616	valid_1's auc: 0.775261	valid_1's binary_logloss: 0.240935
# [500]	training's auc: 0.825976	training's binary_logloss: 0.224049	valid_1's auc: 0.776542	valid_1's binary_logloss: 0.240448
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.825976	training's binary_logloss: 0.224049	valid_1's auc: 0.776542	valid_1's binary_logloss: 0.240448
# |  17       |  0.7765   |  0.8049   |  433.0    |  13.17    |  160.0    |  20.51    |  52.54    |  13.09    |  6.148    |  0.901    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.771511	training's binary_logloss: 0.244802	valid_1's auc: 0.7562	valid_1's binary_logloss: 0.248175
# [200]	training's auc: 0.792278	training's binary_logloss: 0.236481	valid_1's auc: 0.768047	valid_1's binary_logloss: 0.243454
# [300]	training's auc: 0.806388	training's binary_logloss: 0.231158	valid_1's auc: 0.772728	valid_1's binary_logloss: 0.241786
# [400]	training's auc: 0.817956	training's binary_logloss: 0.226889	valid_1's auc: 0.775446	valid_1's binary_logloss: 0.24085
# [500]	training's auc: 0.827545	training's binary_logloss: 0.223343	valid_1's auc: 0.776328	valid_1's binary_logloss: 0.240498
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.827545	training's binary_logloss: 0.223343	valid_1's auc: 0.776328	valid_1's binary_logloss: 0.240498
# |  18       |  0.7763   |  0.9514   |  399.3    |  11.72    |  172.9    |  10.73    |  44.77    |  3.038    |  7.588    |  0.8675   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775361	training's binary_logloss: 0.244363	valid_1's auc: 0.758516	valid_1's binary_logloss: 0.248006
# [200]	training's auc: 0.795302	training's binary_logloss: 0.235713	valid_1's auc: 0.769052	valid_1's binary_logloss: 0.243155
# [300]	training's auc: 0.80967	training's binary_logloss: 0.230232	valid_1's auc: 0.773458	valid_1's binary_logloss: 0.241468
# [400]	training's auc: 0.821519	training's binary_logloss: 0.225836	valid_1's auc: 0.776249	valid_1's binary_logloss: 0.240514
# [500]	training's auc: 0.831834	training's binary_logloss: 0.22206	valid_1's auc: 0.777298	valid_1's binary_logloss: 0.240106
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831834	training's binary_logloss: 0.22206	valid_1's auc: 0.777298	valid_1's binary_logloss: 0.240106
# |  19       |  0.7773   |  0.6493   |  403.4    |  9.831    |  184.4    |  2.989    |  47.78    |  0.02707  |  8.697    |  0.6102   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775224	training's binary_logloss: 0.243733	valid_1's auc: 0.757403	valid_1's binary_logloss: 0.247779
# [200]	training's auc: 0.797602	training's binary_logloss: 0.234708	valid_1's auc: 0.769472	valid_1's binary_logloss: 0.242983
# [300]	training's auc: 0.813487	training's binary_logloss: 0.228765	valid_1's auc: 0.773913	valid_1's binary_logloss: 0.241412
# [400]	training's auc: 0.826561	training's binary_logloss: 0.223914	valid_1's auc: 0.776508	valid_1's binary_logloss: 0.240492
# [500]	training's auc: 0.837499	training's binary_logloss: 0.21983	valid_1's auc: 0.777396	valid_1's binary_logloss: 0.240181
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.837499	training's binary_logloss: 0.21983	valid_1's auc: 0.777396	valid_1's binary_logloss: 0.240181
# |  20       |  0.7774   |  0.9652   |  405.3    |  12.51    |  187.7    |  6.009    |  51.86    |  1.775    |  7.326    |  0.9902   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773285	training's binary_logloss: 0.244442	valid_1's auc: 0.756349	valid_1's binary_logloss: 0.248185
# [200]	training's auc: 0.793997	training's binary_logloss: 0.235924	valid_1's auc: 0.767944	valid_1's binary_logloss: 0.243437
# [300]	training's auc: 0.808421	training's binary_logloss: 0.230463	valid_1's auc: 0.773044	valid_1's binary_logloss: 0.241659
# [400]	training's auc: 0.82026	training's binary_logloss: 0.226089	valid_1's auc: 0.7756	valid_1's binary_logloss: 0.240773
# [500]	training's auc: 0.830482	training's binary_logloss: 0.222238	valid_1's auc: 0.776994	valid_1's binary_logloss: 0.240259
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830482	training's binary_logloss: 0.222238	valid_1's auc: 0.776994	valid_1's binary_logloss: 0.240259
# |  21       |  0.777    |  0.9695   |  444.2    |  14.0     |  159.9    |  20.68    |  52.76    |  8.617    |  7.89     |  0.9558   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776295	training's binary_logloss: 0.243492	valid_1's auc: 0.757351	valid_1's binary_logloss: 0.24785
# [200]	training's auc: 0.798085	training's binary_logloss: 0.234496	valid_1's auc: 0.768859	valid_1's binary_logloss: 0.24316
# [300]	training's auc: 0.813575	training's binary_logloss: 0.228571	valid_1's auc: 0.773374	valid_1's binary_logloss: 0.241538
# [400]	training's auc: 0.826906	training's binary_logloss: 0.223596	valid_1's auc: 0.775996	valid_1's binary_logloss: 0.240629
# [500]	training's auc: 0.838021	training's binary_logloss: 0.219357	valid_1's auc: 0.777145	valid_1's binary_logloss: 0.240218
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.838021	training's binary_logloss: 0.219357	valid_1's auc: 0.777145	valid_1's binary_logloss: 0.240218
# |  22       |  0.7771   |  0.9423   |  432.9    |  13.31    |  166.8    |  23.29    |  55.58    |  5.256    |  4.266    |  0.67     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779335	training's binary_logloss: 0.242427	valid_1's auc: 0.758389	valid_1's binary_logloss: 0.247424
# [200]	training's auc: 0.803086	training's binary_logloss: 0.232753	valid_1's auc: 0.769777	valid_1's binary_logloss: 0.242751
# [300]	training's auc: 0.820235	training's binary_logloss: 0.226245	valid_1's auc: 0.773849	valid_1's binary_logloss: 0.241315
# [400]	training's auc: 0.83418	training's binary_logloss: 0.220926	valid_1's auc: 0.77593	valid_1's binary_logloss: 0.240603
# [500]	training's auc: 0.846029	training's binary_logloss: 0.216327	valid_1's auc: 0.776907	valid_1's binary_logloss: 0.24026
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.846029	training's binary_logloss: 0.216327	valid_1's auc: 0.776907	valid_1's binary_logloss: 0.24026
# |  23       |  0.7769   |  0.9018   |  445.4    |  15.1     |  180.2    |  27.16    |  57.54    |  0.07129  |  3.823    |  0.8962   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779946	training's binary_logloss: 0.243003	valid_1's auc: 0.759758	valid_1's binary_logloss: 0.247626
# [200]	training's auc: 0.800723	training's binary_logloss: 0.233822	valid_1's auc: 0.769599	valid_1's binary_logloss: 0.242908
# [300]	training's auc: 0.8163	training's binary_logloss: 0.227797	valid_1's auc: 0.773533	valid_1's binary_logloss: 0.241415
# [400]	training's auc: 0.829653	training's binary_logloss: 0.222691	valid_1's auc: 0.77629	valid_1's binary_logloss: 0.240462
# [500]	training's auc: 0.841081	training's binary_logloss: 0.218376	valid_1's auc: 0.777516	valid_1's binary_logloss: 0.240041
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.841081	training's binary_logloss: 0.218376	valid_1's auc: 0.777516	valid_1's binary_logloss: 0.240041
# |  24       |  0.7775   |  0.6409   |  445.1    |  12.26    |  163.2    |  39.62    |  58.41    |  2.33     |  2.618    |  0.7822   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.770605	training's binary_logloss: 0.245013	valid_1's auc: 0.755953	valid_1's binary_logloss: 0.248196
# [200]	training's auc: 0.791362	training's binary_logloss: 0.236723	valid_1's auc: 0.768137	valid_1's binary_logloss: 0.24337
# [300]	training's auc: 0.8052	training's binary_logloss: 0.231509	valid_1's auc: 0.77294	valid_1's binary_logloss: 0.241671
# [400]	training's auc: 0.816463	training's binary_logloss: 0.227382	valid_1's auc: 0.775521	valid_1's binary_logloss: 0.240788
# [500]	training's auc: 0.825811	training's binary_logloss: 0.223913	valid_1's auc: 0.776693	valid_1's binary_logloss: 0.240383
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.825811	training's binary_logloss: 0.223913	valid_1's auc: 0.776693	valid_1's binary_logloss: 0.240383
# |  25       |  0.7767   |  0.9424   |  449.0    |  15.52    |  153.2    |  37.26    |  41.79    |  0.4362   |  7.655    |  0.7515   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.780028	training's binary_logloss: 0.242425	valid_1's auc: 0.758424	valid_1's binary_logloss: 0.247498
# [200]	training's auc: 0.803251	training's binary_logloss: 0.232749	valid_1's auc: 0.769457	valid_1's binary_logloss: 0.242932
# [300]	training's auc: 0.820215	training's binary_logloss: 0.22624	valid_1's auc: 0.773617	valid_1's binary_logloss: 0.241433
# [400]	training's auc: 0.834114	training's binary_logloss: 0.220873	valid_1's auc: 0.77611	valid_1's binary_logloss: 0.240561
# [500]	training's auc: 0.845722	training's binary_logloss: 0.216317	valid_1's auc: 0.777003	valid_1's binary_logloss: 0.240198
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.845722	training's binary_logloss: 0.216317	valid_1's auc: 0.777003	valid_1's binary_logloss: 0.240198
# |  26       |  0.777    |  0.9606   |  454.6    |  12.24    |  143.0    |  32.71    |  63.75    |  3.391    |  5.112    |  0.6813   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779495	training's binary_logloss: 0.243451	valid_1's auc: 0.759809	valid_1's binary_logloss: 0.247781
# [200]	training's auc: 0.799607	training's binary_logloss: 0.234343	valid_1's auc: 0.769652	valid_1's binary_logloss: 0.242913
# [300]	training's auc: 0.814952	training's binary_logloss: 0.228355	valid_1's auc: 0.773837	valid_1's binary_logloss: 0.241301
# [400]	training's auc: 0.828256	training's binary_logloss: 0.223344	valid_1's auc: 0.776194	valid_1's binary_logloss: 0.240486
# [500]	training's auc: 0.839759	training's binary_logloss: 0.21896	valid_1's auc: 0.777489	valid_1's binary_logloss: 0.239993
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.839759	training's binary_logloss: 0.21896	valid_1's auc: 0.777489	valid_1's binary_logloss: 0.239993
# |  27       |  0.7775   |  0.6247   |  459.5    |  14.95    |  163.7    |  36.17    |  58.66    |  2.931    |  8.347    |  0.6408   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772328	training's binary_logloss: 0.245613	valid_1's auc: 0.756263	valid_1's binary_logloss: 0.248845
# [200]	training's auc: 0.789861	training's binary_logloss: 0.237761	valid_1's auc: 0.76681	valid_1's binary_logloss: 0.244048
# [300]	training's auc: 0.801657	training's binary_logloss: 0.233172	valid_1's auc: 0.771782	valid_1's binary_logloss: 0.242208
# [400]	training's auc: 0.811371	training's binary_logloss: 0.229533	valid_1's auc: 0.774329	valid_1's binary_logloss: 0.241271
# [500]	training's auc: 0.819872	training's binary_logloss: 0.226351	valid_1's auc: 0.77571	valid_1's binary_logloss: 0.24076
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.819872	training's binary_logloss: 0.226351	valid_1's auc: 0.77571	valid_1's binary_logloss: 0.24076
# |  28       |  0.7757   |  0.7359   |  456.1    |  14.08    |  159.8    |  38.99    |  55.25    |  21.5     |  6.556    |  0.7437   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.778477	training's binary_logloss: 0.242811	valid_1's auc: 0.758307	valid_1's binary_logloss: 0.247492
# [200]	training's auc: 0.801011	training's binary_logloss: 0.233498	valid_1's auc: 0.769483	valid_1's binary_logloss: 0.242863
# [300]	training's auc: 0.817404	training's binary_logloss: 0.227208	valid_1's auc: 0.773815	valid_1's binary_logloss: 0.241317
# [400]	training's auc: 0.831129	training's binary_logloss: 0.221964	valid_1's auc: 0.776402	valid_1's binary_logloss: 0.24046
# [500]	training's auc: 0.842782	training's binary_logloss: 0.21748	valid_1's auc: 0.777386	valid_1's binary_logloss: 0.240113
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.842782	training's binary_logloss: 0.21748	valid_1's auc: 0.777386	valid_1's binary_logloss: 0.240113
# |  29       |  0.7774   |  0.9624   |  453.4    |  13.8     |  177.0    |  49.39    |  59.75    |  3.391    |  3.285    |  0.6039   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.78155	training's binary_logloss: 0.24274	valid_1's auc: 0.759905	valid_1's binary_logloss: 0.247453
# [200]	training's auc: 0.802347	training's binary_logloss: 0.233544	valid_1's auc: 0.769246	valid_1's binary_logloss: 0.242907
# [300]	training's auc: 0.815536	training's binary_logloss: 0.228224	valid_1's auc: 0.772793	valid_1's binary_logloss: 0.241515
# [400]	training's auc: 0.825461	training's binary_logloss: 0.224337	valid_1's auc: 0.774836	valid_1's binary_logloss: 0.240815
# [500]	training's auc: 0.833632	training's binary_logloss: 0.221162	valid_1's auc: 0.776365	valid_1's binary_logloss: 0.240319
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.833632	training's binary_logloss: 0.221162	valid_1's auc: 0.776365	valid_1's binary_logloss: 0.240319
# |  30       |  0.7764   |  0.7229   |  461.3    |  7.894    |  191.3    |  43.69    |  63.61    |  0.4875   |  7.468    |  0.8504   |
# =====================================================================================================================================

# %% [markdown]
# ##### Iteration 수행 결과 출력

# %%
# BayesianOptimization객체의 res는 iteration 수행 시마다 모든 함수 반환결과와 그때의 파라미터 결과값을 가지고 있음. 
lgbBO.res
# Out:
# [{'target': 0.7758055093230539,
#   'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.027633760716439,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917838234820016,
#    'subsample': 0.9818313802505146}},
#  {'target': 0.7756119475191137,
#   'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 11.288949197529044,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20316375600581688,
#    'subsample': 0.916309922773969}},
#  {'target': 0.7773311523552906,
#   'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.78618342232764,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.3995702922539115,
#    'subsample': 0.5716766437045232}},
#  {'target': 0.7749665249476975,
#   'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 10.146619399905235,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18887921456311507,
#    'subsample': 0.8088177485379385}},
#  {'target': 0.774035094542375,
#   'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.437480785146242,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6031944908210691,
#    'subsample': 0.8333833577228338}},
#  {'target': 0.7773907572424612,
#   'params': {'colsample_bytree': 0.640481830861817,
#    'max_bin': 435.0379450370509,
#    'max_depth': 13.497244758196743,
#    'min_child_samples': 169.30259380663517,
#    'min_child_weight': 26.924368410534857,
#    'num_leaves': 57.69153705029583,
#    'reg_alpha': 5.7675960060342195,
#    'reg_lambda': 9.196441703351635,
#    'subsample': 0.6129607288812317}},
#  {'target': 0.7745793981629225,
#   'params': {'colsample_bytree': 0.9147570820732247,
#    'max_bin': 488.66801329033274,
#    'max_depth': 7.188418531106469,
#    'min_child_samples': 187.5933722075758,
#    'min_child_weight': 17.141081285945177,
#    'num_leaves': 62.70402405587779,
#    'reg_alpha': 34.78119017991543,
#    'reg_lambda': 7.949210188043985,
#    'subsample': 0.9046326751527934}},
#  {'target': 0.7775272413784904,
#   'params': {'colsample_bytree': 0.736614785508479,
#    'max_bin': 404.49029787887093,
#    'max_depth': 10.477338234392974,
#    'min_child_samples': 178.59335586781674,
#    'min_child_weight': 7.607190689157394,
#    'num_leaves': 51.9167233300895,
#    'reg_alpha': 4.212212549995254,
#    'reg_lambda': 7.624316599536889,
#    'subsample': 0.8728894918414664}},
#  {'target': 0.7763952615906466,
#   'params': {'colsample_bytree': 0.7748893532024008,
#    'max_bin': 388.9169674423393,
#    'max_depth': 14.298324669842952,
#    'min_child_samples': 193.91589835191607,
#    'min_child_weight': 49.909444261894315,
#    'num_leaves': 62.84933349372062,
#    'reg_alpha': 13.150761788903786,
#    'reg_lambda': 9.906371801724482,
#    'subsample': 0.6811573472682452}},
#  {'target': 0.7744288610358263,
#   'params': {'colsample_bytree': 0.782650462371838,
#    'max_bin': 412.9756510040386,
#    'max_depth': 8.38357428512147,
#    'min_child_samples': 147.30927245980914,
#    'min_child_weight': 3.6119534308305976,
#    'num_leaves': 61.46717561561721,
#    'reg_alpha': 39.48392560608628,
#    'reg_lambda': 8.61318040361951,
#    'subsample': 0.741554910879842}},
#  {'target': 0.7768644681999277,
#   'params': {'colsample_bytree': 0.7784026379931936,
#    'max_bin': 432.29951128875706,
#    'max_depth': 9.27580678631353,
#    'min_child_samples': 156.22269450035915,
#    'min_child_weight': 19.57871212403611,
#    'num_leaves': 62.22792010175759,
#    'reg_alpha': 2.7909547894256,
#    'reg_lambda': 3.4110183609726645,
#    'subsample': 0.9414324335391873}},
#  {'target': 0.7762226212228253,
#   'params': {'colsample_bytree': 0.5333355782501406,
#    'max_bin': 435.4851567367428,
#    'max_depth': 11.746981207456946,
#    'min_child_samples': 184.59151780617952,
#    'min_child_weight': 1.646074433244289,
#    'num_leaves': 27.476641637620965,
#    'reg_alpha': 2.8303335842110826,
#    'reg_lambda': 5.427177603903561,
#    'subsample': 0.9506584413644241}},
#  {'target': 0.7768071427342764,
#   'params': {'colsample_bytree': 0.8216978852568828,
#    'max_bin': 408.45736591150603,
#    'max_depth': 12.66189578868621,
#    'min_child_samples': 176.75610074871113,
#    'min_child_weight': 13.558085592519609,
#    'num_leaves': 45.71182169909841,
#    'reg_alpha': 8.573484273614772,
#    'reg_lambda': 9.075498397071241,
#    'subsample': 0.9440202684110581}},
#  {'target': 0.7766170072106267,
#   'params': {'colsample_bytree': 0.8070104661103596,
#    'max_bin': 383.58288431209195,
#    'max_depth': 9.68869670250472,
#    'min_child_samples': 197.92872438604925,
#    'min_child_weight': 1.590249456757226,
#    'num_leaves': 40.71343480882938,
#    'reg_alpha': 1.1084832873432933,
#    'reg_lambda': 0.5260386173504357,
#    'subsample': 0.7566088965756488}},
#  {'target': 0.7748632743008854,
#   'params': {'colsample_bytree': 0.9906787096965664,
#    'max_bin': 404.2660044128649,
#    'max_depth': 6.113020578011152,
#    'min_child_samples': 176.80963122765579,
#    'min_child_weight': 12.755309613243737,
#    'num_leaves': 55.41705559220205,
#    'reg_alpha': 12.20972718523322,
#    'reg_lambda': 2.7302145158205398,
#    'subsample': 0.6065012922107478}},
#  {'target': 0.7761686584995825,
#   'params': {'colsample_bytree': 0.674474038601589,
#    'max_bin': 427.8604203433535,
#    'max_depth': 7.442297034995114,
#    'min_child_samples': 159.7142211717154,
#    'min_child_weight': 22.295057186958278,
#    'num_leaves': 59.71999050014435,
#    'reg_alpha': 5.4824572410066414,
#    'reg_lambda': 2.533511152885363,
#    'subsample': 0.9365888961317372}},
#  {'target': 0.7765420515711479,
#   'params': {'colsample_bytree': 0.8049127708123405,
#    'max_bin': 432.9794450102791,
#    'max_depth': 13.170789105561521,
#    'min_child_samples': 159.9998794806329,
#    'min_child_weight': 20.508130223447203,
#    'num_leaves': 52.54259117873046,
#    'reg_alpha': 13.09037483603729,
#    'reg_lambda': 6.148289870077169,
#    'subsample': 0.9010369266915803}},
#  {'target': 0.7763281512911566,
#   'params': {'colsample_bytree': 0.9513686848531616,
#    'max_bin': 399.2751305931383,
#    'max_depth': 11.724965270831973,
#    'min_child_samples': 172.9006413180467,
#    'min_child_weight': 10.72951429435603,
#    'num_leaves': 44.76619427898901,
#    'reg_alpha': 3.0376131643072917,
#    'reg_lambda': 7.587715475421446,
#    'subsample': 0.8674855700977073}},
#  {'target': 0.7772981873136251,
#   'params': {'colsample_bytree': 0.6493423525850504,
#    'max_bin': 403.36433852024453,
#    'max_depth': 9.830831501739713,
#    'min_child_samples': 184.38825344950172,
#    'min_child_weight': 2.9893467697413327,
#    'num_leaves': 47.78144496430117,
#    'reg_alpha': 0.02706747462649948,
#    'reg_lambda': 8.69691076695145,
#    'subsample': 0.6101730334721724}},
#  {'target': 0.7773956417171454,
#   'params': {'colsample_bytree': 0.9652251061057102,
#    'max_bin': 405.31682351979305,
#    'max_depth': 12.510433568983224,
#    'min_child_samples': 187.73180490822176,
#    'min_child_weight': 6.008899334054026,
#    'num_leaves': 51.85802236644921,
#    'reg_alpha': 1.7747969963939738,
#    'reg_lambda': 7.325936229346423,
#    'subsample': 0.9901521077678885}},
#  {'target': 0.7769941442518931,
#   'params': {'colsample_bytree': 0.9694572631554397,
#    'max_bin': 444.2303414756819,
#    'max_depth': 14.000231745963585,
#    'min_child_samples': 159.91299562993436,
#    'min_child_weight': 20.681429069560544,
#    'num_leaves': 52.76009475818188,
#    'reg_alpha': 8.617013772077534,
#    'reg_lambda': 7.890145195250425,
#    'subsample': 0.9558339992559453}},
#  {'target': 0.7771453517036451,
#   'params': {'colsample_bytree': 0.9422774565965977,
#    'max_bin': 432.901127494436,
#    'max_depth': 13.31053943997927,
#    'min_child_samples': 166.77905663554327,
#    'min_child_weight': 23.28553184405287,
#    'num_leaves': 55.575924732862816,
#    'reg_alpha': 5.25580377631261,
#    'reg_lambda': 4.266373836256442,
#    'subsample': 0.6700437819134917}},
#  {'target': 0.7769066112886583,
#   'params': {'colsample_bytree': 0.9017999208126606,
#    'max_bin': 445.3849286006298,
#    'max_depth': 15.099510690653442,
#    'min_child_samples': 180.2164994879414,
#    'min_child_weight': 27.15939317737522,
#    'num_leaves': 57.54169579420305,
#    'reg_alpha': 0.0712870146391045,
#    'reg_lambda': 3.822514683438758,
#    'subsample': 0.8961764300247357}},
#  {'target': 0.7775164224656207,
#   'params': {'colsample_bytree': 0.6408777738273136,
#    'max_bin': 445.12624959092267,
#    'max_depth': 12.259544684860595,
#    'min_child_samples': 163.19576953315902,
#    'min_child_weight': 39.62354478441969,
#    'num_leaves': 58.407065615007426,
#    'reg_alpha': 2.3295914358859933,
#    'reg_lambda': 2.6176567712956422,
#    'subsample': 0.7822395487530219}},
#  {'target': 0.7766934401058638,
#   'params': {'colsample_bytree': 0.942413882464241,
#    'max_bin': 448.98922271546786,
#    'max_depth': 15.52262208603468,
#    'min_child_samples': 153.18756607558058,
#    'min_child_weight': 37.257226938573375,
#    'num_leaves': 41.78684275549829,
#    'reg_alpha': 0.4361959088537941,
#    'reg_lambda': 7.654683497417176,
#    'subsample': 0.7514761229984483}},
#  {'target': 0.7770029077142777,
#   'params': {'colsample_bytree': 0.9605763430317431,
#    'max_bin': 454.5679962864518,
#    'max_depth': 12.24376554974615,
#    'min_child_samples': 142.98212098294653,
#    'min_child_weight': 32.70576430913964,
#    'num_leaves': 63.746103110766555,
#    'reg_alpha': 3.3914183305837584,
#    'reg_lambda': 5.111571196121858,
#    'subsample': 0.6812727842189634}},
#  {'target': 0.7774886214653207,
#   'params': {'colsample_bytree': 0.6247431330168589,
#    'max_bin': 459.4710486011218,
#    'max_depth': 14.952333011571161,
#    'min_child_samples': 163.74108510289872,
#    'min_child_weight': 36.17376060553607,
#    'num_leaves': 58.661813369018795,
#    'reg_alpha': 2.9314724605255673,
#    'reg_lambda': 8.347269747081947,
#    'subsample': 0.6407699650139498}},
#  {'target': 0.7757097116698088,
#   'params': {'colsample_bytree': 0.7358771746830932,
#    'max_bin': 456.08675638420004,
#    'max_depth': 14.080034702288017,
#    'min_child_samples': 159.84595424144035,
#    'min_child_weight': 38.99124918026897,
#    'num_leaves': 55.248503996117776,
#    'reg_alpha': 21.50447768322377,
#    'reg_lambda': 6.555565449851929,
#    'subsample': 0.7437152717003979}},
#  {'target': 0.7773859410710003,
#   'params': {'colsample_bytree': 0.9623608330933966,
#    'max_bin': 453.3912905710999,
#    'max_depth': 13.801214910084422,
#    'min_child_samples': 177.00358780600027,
#    'min_child_weight': 49.38521641734111,
#    'num_leaves': 59.7454556046699,
#    'reg_alpha': 3.391218661519,
#    'reg_lambda': 3.284733619354344,
#    'subsample': 0.6038803103705016}},
#  {'target': 0.7763647427574412,
#   'params': {'colsample_bytree': 0.7228520190964621,
#    'max_bin': 461.27384950983395,
#    'max_depth': 7.893524542547627,
#    'min_child_samples': 191.27029205197047,
#    'min_child_weight': 43.688728198394315,
#    'num_leaves': 63.60803963045017,
#    'reg_alpha': 0.4874666242800964,
#    'reg_lambda': 7.467583977647125,
#    'subsample': 0.8503533653009046}}]

# %% [markdown]
# ##### Iteration 결과 Dictionary에서 최대 target값을 가지는 index 추출하고 그때의 parameter 값을 추출.

# %%
# dictionary에 있는 target값을 모두 추출
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
# 가장 큰 target 값을 가지는 순번(index)를 추출
print('maximum target index:', np.argmax(np.array(target_list)))
# Out:
# [0.7758055093230539, 0.7756119475191137, 0.7773311523552906, 0.7749665249476975, 0.774035094542375, 0.7773907572424612, 0.7745793981629225, 0.7775272413784904, 0.7763952615906466, 0.7744288610358263, 0.7768644681999277, 0.7762226212228253, 0.7768071427342764, 0.7766170072106267, 0.7748632743008854, 0.7761686584995825, 0.7765420515711479, 0.7763281512911566, 0.7772981873136251, 0.7773956417171454, 0.7769941442518931, 0.7771453517036451, 0.7769066112886583, 0.7775164224656207, 0.7766934401058638, 0.7770029077142777, 0.7774886214653207, 0.7757097116698088, 0.7773859410710003, 0.7763647427574412]
# maximum target index: 7

# %%
# 가장 큰 target값을 가지는 index값을 기준으로 res에서 해당 parameter 추출. 
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7775272413784904, 'params': {'colsample_bytree': 0.736614785508479, 'max_bin': 404.49029787887093, 'max_depth': 10.477338234392974, 'min_child_samples': 178.59335586781674, 'min_child_weight': 7.607190689157394, 'num_leaves': 51.9167233300895, 'reg_alpha': 4.212212549995254, 'reg_lambda': 7.624316599536889, 'subsample': 0.8728894918414664}}

# %% [markdown]
# ##### 최적화된 하이퍼 파라미터를 기반으로 재 테스트

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 10,
                num_leaves=52,
                colsample_bytree=0.736,
                subsample=0.872,
                max_bin=404,
                reg_alpha=4.212,
                reg_lambda=7.624,
                min_child_weight=8,
                min_child_samples=179,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)
# train shape: (215257, 174) valid shape: (92254, 174)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776113	training's binary_logloss: 0.244087	valid_1's auc: 0.758488	valid_1's binary_logloss: 0.247925
# [200]	training's auc: 0.795984	training's binary_logloss: 0.23549	valid_1's auc: 0.768933	valid_1's binary_logloss: 0.243191
# [300]	training's auc: 0.810008	training's binary_logloss: 0.230053	valid_1's auc: 0.773314	valid_1's binary_logloss: 0.241552
# [400]	training's auc: 0.822241	training's binary_logloss: 0.225469	valid_1's auc: 0.776191	valid_1's binary_logloss: 0.240529
# [500]	training's auc: 0.832604	training's binary_logloss: 0.221581	valid_1's auc: 0.777439	valid_1's binary_logloss: 0.240065
# [600]	training's auc: 0.841785	training's binary_logloss: 0.218122	valid_1's auc: 0.778176	valid_1's binary_logloss: 0.239784
# [700]	training's auc: 0.850158	training's binary_logloss: 0.21493	valid_1's auc: 0.778643	valid_1's binary_logloss: 0.239637
# [800]	training's auc: 0.857956	training's binary_logloss: 0.211875	valid_1's auc: 0.77899	valid_1's binary_logloss: 0.239518
# [900]	training's auc: 0.865164	training's binary_logloss: 0.208939	valid_1's auc: 0.77907	valid_1's binary_logloss: 0.239483
# [1000]	training's auc: 0.872056	training's binary_logloss: 0.20611	valid_1's auc: 0.778877	valid_1's binary_logloss: 0.23952
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.872056	training's binary_logloss: 0.20611	valid_1's auc: 0.778877	valid_1's binary_logloss: 0.23952

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv('prev_baseline_tuning_01.csv', index=False)

# %% [markdown]
# ## Private Score 0.76714 / Public Score 0.77632
